# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import geopandas as gpd

# %%
limite_as = gpd.read_file('lim_pais_a.shp')
limite_bacias = gpd.read_file('GEOFT_BHO_REF_ACH_n1.shp')

# %%
limite_as.head()
# Out:
#                         nome  ...                                           geometry
# 0                     Brasil  ...  MULTIPOLYGON (((-28.85365 -20.47547, -28.85372...
# 1                      Chile  ...  MULTIPOLYGON (((-67.24908 -55.97526, -67.27164...
# 2                    Ecuador  ...  MULTIPOLYGON (((-80.07488 -2.93137, -80.08265 ...
# 3  Falkland Islands/Malvinas  ...  MULTIPOLYGON (((-39.10368 -53.97896, -39.04586...
# 4                     Panamá  ...  MULTIPOLYGON (((-81.78940 7.27305, -81.79500 7...
#
# [5 rows x 8 columns]

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111)
limite_as.plot(ax=ax, color='grey', alpha=0.2, linestyle='--', linewidth=1,
               edgecolor='k')
limite_bacias[8:9].plot(ax=ax, color='b', alpha=0.4)

#import matplotlib.patches as mpatches
#red_patch = mpatches.Patch(color='b', alpha=0.4, label='Bacia do Rio Paraná')
#plt.legend(handles=[red_patch], frameon=False, fontsize=12)

# %%
limite_as.plot(cmap='Pastel2', column='nome', linestyle='--', linewidth=1, edgecolor='k')

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
world.head()
# Out:
#      pop_est  ...                                           geometry
# 0     920938  ...  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1   53950935  ...  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2     603253  ...  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3   35623680  ...  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4  326625791  ...  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...
#
# [5 rows x 6 columns]

# %%
data = world.loc[:, ['name', 'iso_a3', 'gdp_md_est', 'geometry']].copy()

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable

fig, ax = plt.subplots(1, 1, figsize=(10, 8))

divider = make_axes_locatable(ax)

cax = divider.append_axes("right", size="5%", pad=0.1)

data.plot(column='gdp_md_est', cmap='OrRd', linewidth=1, edgecolor='k', legend=True, ax=ax, cax=cax)

# %%
# Mesorregiões
meso = gpd.read_file('BRMEE250GC_SIR.shp')

# %%
meso.head()
# Out:
#                          NM_MESO  ...                                           geometry
# 0  VALE SÃO-FRANCISCANO DA BAHIA  ...  POLYGON ((-43.91589 -10.39308, -43.91479 -10.3...
# 1                SUL CATARINENSE  ...  MULTIPOLYGON (((-48.60210 -28.35256, -48.60215...
# 2                 OESTE POTIGUAR  ...  MULTIPOLYGON (((-37.04412 -4.81854, -37.04501 ...
# 3                  CENTRO GOIANO  ...  POLYGON ((-49.93862 -15.74910, -49.93984 -15.7...
# 4             SUDESTE PARANAENSE  ...  POLYGON ((-50.96336 -25.68256, -50.96464 -25.6...
#
# [5 rows x 3 columns]

# %%
meso.plot()

# %%
meso1 = meso.loc[meso.NM_MESO.isin(['VALE DO PARAÍBA PAULISTA', 'SUL/SUDOESTE DE MINAS'])]

# %%
meso1
# Out:
#                       NM_MESO  ...                                           geometry
# 79   VALE DO PARAÍBA PAULISTA  ...  MULTIPOLYGON (((-45.66346 -24.08258, -45.66339...
# 105     SUL/SUDOESTE DE MINAS  ...  POLYGON ((-46.51184 -21.56538, -46.51181 -21.5...
#
# [2 rows x 3 columns]

# %%
meso1.plot(column='NM_MESO', cmap='Set3')

# %%
uf = gpd.read_file('lim_unidade_federacao_a.shp')

# %%
uf.head()
# Out:
#              nome  ...                                           geometry
# 0           Bahia  ...  MULTIPOLYGON (((-38.71080 -17.96966, -38.70848...
# 1            Pará  ...  MULTIPOLYGON (((-46.45928 -0.90961, -46.45936 ...
# 2  Rio de Janeiro  ...  MULTIPOLYGON (((-43.55929 -23.08050, -43.55938...
# 3       São Paulo  ...  MULTIPOLYGON (((-45.13777 -23.79018, -45.13777...
# 4  Espírito Santo  ...  MULTIPOLYGON (((-28.85365 -20.47547, -28.85372...
#
# [5 rows x 8 columns]

# %%
uf.plot(column='nome', cmap='Set3', linewidth=1, edgecolor='grey')

# %%
mun = gpd.read_file('Municipios_BRASIL_SIRGAS2000.shp')

# %%
itajuba = mun.loc[mun.nome.isin(['Itajubá'])]

# %%
itajuba.plot(edgecolor='k', facecolor='none')

# %%
mun.plot(alpha=0.5, edgecolor='k', linewidth=0.2)
